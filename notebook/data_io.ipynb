# %%
import pandas as pd
import numpy as np
import pickle
import datetime

# %%
url = "https://raw.githubusercontent.com/kohjiaxuan/Predicting-HDB-Price-with-Machine-Learning/master/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv"
data = pd.read_csv(url)

# %%
# Save to WSL drive (default home directory or specify path)
# Save to current WSL directory
# index=False prevents pandas from adding an extra index column
data.to_csv('../dataset/hdb_resale_prices.csv', index=False)
print(f"Data saved successfully! Shape: {data.shape}")
# Out:
# Data saved successfully! Shape: (50432, 11)
